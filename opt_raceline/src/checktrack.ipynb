# %%
import import_geojson_gps_centerline as iggc
import plot_track as pt



result = iggc.import_geojson_gps_centerline('../input/centerlines/Leipzig.geojson')
#pt.plot_track(result, result)
# Out:
# WARNING: Did not find a perfectly matching section, minimum distance is 0.04m!
# WARNING: Did not find a perfectly matching section, minimum distance is 0.00m!
